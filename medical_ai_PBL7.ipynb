# %% [markdown]
# # PBL7 Building medical chatbots for constrained outputs

# %% [markdown]
# # Start of PBL
#
# Congratulations on making it to the PBL7 Building medical chatbots for constrained outputs! Now time to put everything together and learn how to **create unique and complex prompts** for medical chatbots.
#
# Below, you will be using a **guided structure that we recommend for complex prompts**.
#
# **Note:** **Not all prompts need every element of the following complex structure**. We encourage you to play around with various prompt engineering techniques (https://www.promptingguide.ai/) and include or disinclude elements and see how it affects LLM's response. It is usually **best to use many prompt elements to get your prompt working first, then refine and slim down your prompt afterward**.
#
# We have shown you an example of EHR report data extraction during the class, in this PBL, we would like you to apply and reflect on the different prompting strategies and best practices of prompt engineering to craft your **own** prompt for this EHR report data extraction task and genetic counselling.

# %% [markdown]
# ### Example - EHR report data extraction chatbot
#
# The following structure combines multiple prompt engineering elements and is a good starting point for complex prompts. **The ordering matters for some elements**, not for others. We will note when best practices indicate ordering matters, but in general, **if you stick to this ordering, it will be a good start to a stellar prompt**.
#
# For the following example, we will be building a prompt for a controlled roleplay wherein LLMs takes on a situational role with a specific task. Our goal is to prompt LLMs to act as a friendly career coach.
#
# Read then run the cell below to compile the various prompt elements into one whole prompt.

# %%
######################################## PROMPT ELEMENTS ########################################

##### Prompt element 1: Role definition
# Make sure that your call always starts with a role in the messages array.
ROLE_CONTEXT = "You are a clinical clerk assistant designed to extract structured medical information from electronic health records (EHRs)."

##### Prompt element 2: Task context
# Give context about the role it should take on or what goals and overarching tasks you want it to undertake with the prompt.
# It's best to put context early in the body of the prompt.
TASK_CONTEXT = "Your task is to analyze the EHR content and extract all relevant information into predefined categories. Complete the fields below using the EHRs. Include only events that occurred before the most recent ED admission, and exclude any test results collected afterward."

##### Prompt element 3: Tone context
# If important to the interaction, tell LLM what tone it should use.
# This element may not be necessary depending on the task.
TONE_CONTEXT = "Keep your response in a professional and advisory tone."

##### Prompt element 4: Detailed task description and rules
# Expand on the specific tasks you want to do, as well as any rules that LLM might have to follow.
# It's ideal to show this description and rules to a friend to make sure it is laid out logically and that any ambiguous words are clearly defined.
TASK_DESCRIPTION = """
Gather the patient's medical history, which typically includes:
- Basic Information: Patient name, age, gender, and other relevant demographics.
- Chief Complaint: Use the OLD CARTS framework (Onset, Location, Duration, Characteristics, Alleviating/Aggravating factors, Radiation/Relieving factors, Tim-ing, Severity) implicitly, without explicitly mentioning each step.
- Past Medical History: Previous illnesses, surgeries, or chronic conditions.
- Allergies: Known allergies to medications, foods, or other substances.
- Medications: Current or recent medications, including supplements.
- Social History: Lifestyle factors such as smoking, alcohol use, drug use (including illicit substances), and mental health.
- Family History: Significant or hereditary health conditions present in the family.
"""

##### Prompt element 5: Examples
# Provide at least one example of an ideal response that it can emulate. Encase this in <example></example> XML tags. Feel free to provide multiple examples.
# If you do provide multiple examples, give context about what it is an example of, and enclose each example in its own set of XML tags.
# Examples are probably the single most effective tool in knowledge work for getting LLM to behave as desired.
# Make sure to give LLM examples of common edge cases. If your prompt uses a scratchpad, it's effective to give examples of how the scratchpad should look.
# Generally more examples = better.
EXAMPLES = """Here is an example of how to respond in a standard interaction:
<example>
[Insert your example]
</example>"""

##### Prompt element 6: Input data to process
# If there is data that LLM needs to process within the prompt, include it here within relevant XML tags.
# Feel free to include multiple pieces of data, but be sure to enclose each in its own set of XML tags.
# This element may not be necessary depending on task. Ordering is also flexible.
INPUT_DATA = f"""Given the medical report (.pdf) of a patient."""

##### Prompt element 7: Immediate task description or request #####
# "Remind" LLM or tell it exactly what it's expected to immediately do to fulfill the prompt's task.
# This is also where you would put in additional variables like the user's question.
# It generally doesn't hurt to reiterate to LLM its immediate task. It's best to do this toward the end of a long prompt.
# This will yield better results than putting this at the beginning.
# It is also generally good practice to put the user's query close to the bottom of the prompt.
IMMEDIATE_TASK = "[Insert your immediate task where appropriate]"

##### Prompt element 8: Precognition (thinking)
# For tasks with multiple steps, it's good to tell LLMs to think step by step before giving an answer
# Sometimes, you might have to even say "Before you give your answer..." just to make sure LLMs does this first.
# Not necessary with all prompts, though if included, it's best to do this toward the end of a long prompt and right after the final immediate task request or description.
PRECOGNITION = """
[Insert your prompt engineering techniques for precognition]
"""

##### Prompt element 9: Output formatting
# If there is a specific way you want LLM's response formatted, clearly tell LLM what that format is.
# This element may not be necessary depending on the task.
# If you include it, putting it toward the end of the prompt is better than at the beginning.
OUTPUT_FORMATTING = """
Return the extracted information in the following valid format.
Guidelines:
1. Extract each field from the entire EHR with complete accuracy.
2. Keep each field concise and keyword-based phrases without full sentences or narrative descriptions.
3. Express information briefly, avoiding verbs, pronouns, or unnecessary words.
4. If a field contains multiple values, combine them into a single string separated by semi-colons.
5. Treat de-identified placeholders as nonexistent. Do not include placeholders like '_' in any of output fields.
6. Return 'Not recorded' for any field not mentioned in the EHR.
"""

##### Final prompt
FINALPROMPT = """
You are a clinical clerk assistant designed to extract structured medical information from electronic health records (EHRs).
Your task is to analyze the EHR content and extract all relevant information into predefined categories. Complete the fields below using the EHRs. Include only events that occurred before the most recent ED admission, and exclude any test results collected afterward. Return the extracted information in the following valid format.
Given the medical report (.pdf) of a patient.
Gather the patient's medical history, which typically includes:
- Basic Information: Patient name, age, gender, and other relevant demographics.
- Chief Complaint: Use the OLD CARTS framework (Onset, Location, Duration, Characteristics, Alleviating/Aggravating factors, Radiation/Relieving factors, Tim-ing, Severity) implicitly, without explicitly mentioning each step.
- Past Medical History: Previous illnesses, surgeries, or chronic conditions.
- Allergies: Known allergies to medications, foods, or other substances.
- Medications: Current or recent medications, including supplements.
- Social History: Lifestyle factors such as smoking, alcohol use, drug use (including illicit substances), and mental health.
- Family History: Significant or hereditary health conditions present in the family.

Guidelines:
1. Extract each field from the entire EHR with complete accuracy.
2. Keep each field concise and keyword-based phrases without full sentences or narrative descriptions.
3. Express information briefly, avoiding verbs, pronouns, or unnecessary words.
4. If a field contains multiple values, combine them into a single string separated by semi-colons.
5. Treat de-identified placeholders as nonexistent. Do not include placeholders like '_' in any of output fields.
6. Return 'Not recorded' for any field not mentioned in the EHR.

Keep your response in a professional and advisory tone.
"""

# %% [markdown]
# ## Problem 1.1 EHRs report data extraction

# %% [markdown]
# Objective: Use prompt engineering to extract structured patient information from unstructured clinical notes.
#
# Steps:
#
# Download clinical report PDF files from Moodle PBL7 "EHR" folder.
#
# Design a prompt that instructs the LLM to extract the following fields for each report/patient:
#
# - Basic Information (name, age, gender)
# - Chief Complaint
# - Past Medical History
# - Allergies
# - Medications
# - Social History
# - Family History
#
# Run your prompt using the HKU ChatGPT portal (https://chatgpt.hku.hk/) or your chosen LLM.
#
# Please document:
# - Your final prompt
# - The LLM output
# - A reflection (max 300 words) on challenges, strengths/efficiency, and limitations of using varous LLMs and prompting strategies for this task.

# %%
#in this section i explore 4 various prompts and try to find what is suituable in this context based on their outputs 
Prompt:

1: 
'''You are a clinician assistant that extracts data from EHR reports. I will act as the clinician and provide EHR pdfs and I want you to extract the following specified information from specific categories already enlisted in the pdf for each patient:

- Basic information: name, age and gender 
- Chief complaints  
- Past medical history listed in a table with each important section as a column including chronic conditions, past illness, surgeries, allergies and medications 
- Social history as a separate table including all smoking, alcohol, illicit drugs, occupation 
- Family history in a list  

 Some guidelines to follow: values that are not specified are written as N/A in tables, do not extract entire paragraphs or sentences, only key information specified, ensure values are same as EHR '''

2: 
#I have chosen this as my FINAL PROMPT 
'''You are a clinical clerk assistant. Analyse the attached EHR and extract this information: 
Basic Information 
Chief Complaint 
Past Medical History 
Allergies 
Medications 
Social History 
Family History 
- make each section concise, and write 'N/A' for missing fields.'''

3:
'''
Extract clinically relevant information from this attached EHRs report
'''

4:
'''
Extract important clinically relevant information from this attached EHRs report. Be consise, dont include uneccessary detail, where values are not states, please write N/A
'''

# %%
Output:
1:
#(past medical history, social history are both provided as tables as specified in prompt but in this code cell are not formatted correctly)
'''Basic Information 
Name: Amanda J Ruiz  
Age: 47  
Gender: Female  

Chief Complaints 
- Bacteremia  
-Possible mediastinitis  

Past Medical History 
Chronic Conditions 
CAD s/p CABG, Type 2 Diabetes Mellitus, Hypertension, Hyperlipidemia, LBBB s/p pacemaker,Carotid artery stenosis, CKD, COPD, Obesity

Past Illness 
CVA with left-sided hemiparesis, Peptic ulcer disease, Basal cell carcinoma (face), Prostate cancer

Surgeries 
CABG, Pacemaker placement, Basal cell carcinoma excision

Allergies
Sulfa, Aricept, Lidocaine, Penicillins, Cipro

Medications 
Insulin, Losartan, Metoprolol, Rosuvastatin, Aspirin, Fluticasone, Tiotropium, Albuterol, Vitamin D

Social History
Smoking
Former Smoker

Alcohol
N/A

Illicit Drugs
N/A

Occupation
N/A

Family History

No pertinent family history
'''

2: 
'''
Basic Information
Name: Amanda J Ruiz
Age: 47
Gender: Female

Chief Complaint
Bacteremia; possible mediastinitis

Past Medical History
CAD s/p CABG; Type 2 Diabetes Mellitus; Hypertension; Hyperlipidemia; LBBB s/p pacemaker; Carotid artery stenosis; CKD; COPD; Obesity; CVA with left-sided hemiparesis; Peptic ulcer disease; Basal cell carcinoma (s/p excision); Prostate cancer

Allergies
Sulfa; Aricept; Lidocaine; Penicillins; Cipro

Medications
Insulin; Losartan; Metoprolol; Rosuvastatin; Aspirin; Fluticasone; Tiotropium; Albuterol; Vitamin D

Social History
Smoking: Former smoker
Alcohol: N/A
Illicit Drugs: N/A
Occupation: N/A

Family History
No pertinent family history
'''

3:
'''
Here is a clinically relevant summary of the EHR:

Patient Overview
- Name: Amanda J Ruiz
- Age: 47
- Gender: Female (note: conflicting documentation—clinical narrative describes male)

Presenting Problem
- Primary issue: Mediastinitis with polymicrobial bacteremia (GBS, MRSA)
- Symptoms: Malaise, nausea, vomiting, diarrhea, chest discomfort
- Duration: ~6 days prior to admission

Key Diagnoses
Primary
- Post-sternotomy mediastinitis with polymicrobial bacteremia
Secondary
- Acute kidney injury
- Decompensated heart failure (EF 45%)
- Type 2 Diabetes Mellitus
- Hypertension
- History of CVA with hemiparesis
- COPD
- Obesity

Relevant Past Medical History
- CAD s/p CABG
- Diabetes (with neuropathy)
- Hypertension, hyperlipidemia
- CKD
- COPD
- LBBB with pacemaker
- CVA (residual deficit)
- Malignancies: prostate cancer, basal cell carcinoma

Investigations
Imaging
- CT chest: Mediastinal fluid collection extending toward pericardium
- MRI spine: Lumbar epidural abscess + paraspinal abscess
- CT abdomen: Colitis, diverticulosis
- CXR: Mild atelectasis

Labs (abnormal highlights)
- Leukocytosis (WBC 17.5)
- Anemia (Hb ~9)
- AKI (Cr ~2.0)
- Hyponatremia (Na 129)
- Elevated CRP
- Elevated liver enzymes (AST, ALT, ALP)

Management
- Surgical
- Sternal wound and mediastinal debridement
- VAC dressing placement

Medical
- IV Daptomycin (MRSA)
- IV Cefepime (GBS)
- IV fluids for AKI
- Insulin therapy
- Temporary pacemaker (bradycardia)

Clinical Course
- 13-day hospitalization
- Gradual resolution of bacteremia
- Improvement in inflammatory markers

Follow-Up Needs
- Cardiothoracic surgery (wound care)
- Infectious disease (antibiotics)
- Cardiology (heart failure)
- Endocrinology (diabetes)

Key Clinical Concerns
- Severe post-surgical infection (mediastinitis)
- Multisite infection (mediastinum + epidural abscess)
- High-risk comorbidities (DM, CAD, CKD)
- Documentation inconsistency (gender mismatch)

If you want, I can convert this into a SOAP note, handover summary, or OSCE-style presentation.
'''

4:
'''
Here is a concise extraction of clinically relevant information from the EHR:

Patient Demographics
- Age: 47
- Sex: Male (note: conflicting entries show female)
- DOB: 1976-09-23
- MRN: M370216
- Admission: 2023-09-30
- Discharge: 2023-10-13

Chief Complaint
- Bacteremia and suspected mediastinitis

Primary Diagnosis
- Post-sternotomy mediastinitis with polymicrobial bacteremia (GBS, MRSA)
Secondary Diagnoses
- Acute kidney injury (Cr 2.0–2.2)
- Decompensated heart failure (EF 45%)
- Type 2 diabetes mellitus
- Hypertension
- History of CVA with left hemiparesis
- COPD
- Obesity
- Hyponatremia
- Anemia

Key Clinical Findings
- Fever: Tmax 101°F
- Leukocytosis: WBC 17.5
- Elevated CRP: 24.5
- CT chest: mediastinal fluid collection with possible pericardial involvement

Microbiology
- Blood cultures:
- Group B Streptococcus (GBS)
- MRSA

Important Imaging
- CT chest: mediastinal fluid collection
- MRI spine: lumbar epidural abscess + paraspinal abscess
- CT abdomen: colitis (infectious/inflammatory)
- CXR: mild basilar atelectasis

Pertinent Laboratory Abnormalities
- Na: 127–129 (low)
- Creatinine: 2.0 (high)
- BUN: 53 (high)
- Glucose: 187 (high)
- WBC: 17.5 (high)
- Hemoglobin: ~9.0 (low)
- Albumin: 2.7 (low)
- ALP: 342 (high)
- PT/INR: 27.3 / 2.5 (high)
- PTT: 56.3 (high)

Past Medical History
- CAD s/p CABG
- Type 2 diabetes mellitus
- Hypertension
- CKD
- COPD
- CVA with residual deficit
- Carotid artery stenosis
- LBBB with pacemaker
- Hyperlipidemia
- Obesity

Allergies
- Sulfa drugs
- Penicillins
- Ciprofloxacin
- Lidocaine
- Aricept

Hospital Management
- Surgical debridement + VAC dressing
- IV antibiotics:
    - Daptomycin
    - Cefepime
- IV fluids for AKI
- Insulin therapy
- Temporary pacemaker placement

Discharge Medications
- Cefepime IV
- Insulin glargine
- Metoprolol
- Lisinopril
- Rosuvastatin
- Fluticasone/Salmeterol

Follow-Up
- Cardiothoracic surgery (1 week)
- Infectious disease (2 weeks)
- Cardiology (2 weeks)
- Endocrinology (1 month)
- Primary care (2 weeks)

Disposition
- Discharged home with home health support and VAC therapy

Other Relevant
- Smoking: Former
- Alcohol: N/A
- Illicit drugs: N/A

If you want, I can convert this into a structured clinical summary (SOAP note / handover format) or a problem list with priorities.
'''

# %% [markdown]
# Prompt A - best prompt (prompt 2):
#
# You are a clinical clerk assistant. Analyse the attached EHR and extract this information:
#
# Basic Information
#
# Chief Complaint
#
# Past Medical History
#
# Allergies
#
# Medications
#
# Social History
#
# Family History
#
# make each section concise, and write 'N/A' for missing fields.

# %% [markdown]
# Output A:
#
# **Basic Information**
# Name: Amanda J Ruiz
# Age: 47
# Gender: Female
#
# **Chief Complaint**
# Bacteremia; possible mediastinitis
#
# **Past Medical History**
# CAD s/p CABG; Type 2 Diabetes Mellitus; Hypertension; Hyperlipidemia; LBBB s/p pacemaker; Carotid artery stenosis; CKD; COPD; Obesity; CVA with left-sided hemiparesis; Peptic ulcer disease; Basal cell carcinoma (s/p excision); Prostate cancer
#
# **Allergies**
# Sulfa; Aricept; Lidocaine; Penicillins; Cipro
#
# **Medications**
# Insulin; Losartan; Metoprolol; Rosuvastatin; Aspirin; Fluticasone; Tiotropium; Albuterol; Vitamin D
#
# **Social History**
# Smoking: Former smoker
# Alcohol: N/A
# Illicit Drugs: N/A
# Occupation: N/A
#
#
# **Family History**
# No pertinent family history

# %% [markdown]
# Prompt B - second best prompt (prompt 1):
#
# You are a clinician assistant that extracts data from EHR reports. I will act as the clinician and provide EHR pdfs and I want you to extract the following specified information from specific categories already enlisted in the pdf for each patient:
#
# - Basic information: name, age and gender
#
# - Chief complaints
#
# - Past medical history listed in a table with each important section as a column including chronic conditions, past illness, surgeries, allergies and medications
#
# - Social history as a separate table including all smoking, alcohol, illicit drugs, occupation
#
# - Family history in a list
#
#
# Some guidelines to follow: values that are not specified are written as N/A in tables, do not extract entire paragraphs or sentences, only key information specified, ensure values are same as EHR

# %% [markdown]
# Output B:
#
# **Basic Information**
# Name: Amanda J Ruiz
# Age: 47
# Gender: Female
#
# **Chief Complaints**
# - Bacteremia
# - Possible mediastinitis
#
# **Past Medical History**
# | Chronic Conditions | Past Illness | Surgeries | Allergies | Medications |
# |-------------------|-------------|-----------|-----------|-------------|
# | CAD s/p CABG; Type 2 Diabetes Mellitus; Hypertension; Hyperlipidemia; LBBB s/p pacemaker; Carotid artery stenosis; CKD; COPD; Obesity | CVA with left-sided hemiparesis; Peptic ulcer disease; Basal cell carcinoma; Prostate cancer | CABG; Pacemaker placement; Basal cell carcinoma excision | Sulfa; Aricept; Lidocaine; Penicillins; Cipro | Insulin; Losartan; Metoprolol; Rosuvastatin; Aspirin; Fluticasone; Tiotropium; Albuterol; Vitamin D |
#
#
# **Social History**
# | Smoking | Alcohol | Illicit Drugs | Occupation |
# |--------|--------|--------------|------------|
# | Former smoker | N/A | N/A | N/A |
#
# **Family History**
# - No pertinent family history

# %% [markdown]
# ## Problem 1.2 Laboratory report analysis

# %% [markdown]
# Objective: Extract structured laboratory information and derive actionable findings.
#
# Steps:
#
# Use the same clinical report PDF files in Moodle PBL7 "EHR" folder, they contains laboratory reports.
#
# Design a prompt that extracts:
# - Brief summary, patient demographics, reason for testing
# - Items tested, abnormalities flagged
# - Disease identified, interpretations
# - Actionable items: follow-up tests, treatment recommendations
#
#
# Please document:
# - Your final prompt
# - The LLM output
# - A reflection (max. 300 words) on comparing accuracy of various prompting strategies and different LLMs to extract the useful lab tests information.

# %%
Prompt:

1. 
'''
 extract  structured laboratory information and derive actionable findings
'''

2. 
'''
You are a clinical clerk assistant. You must extract structured laboratory information and derive actionable findings from the attached lab report after analysing and dividing into specific segments of data: 

- Brief summary of the report 
- Patient 
- Demographics 
- Reason for testing 
- Items tested 
- Abnormalities flagged  
- Disease identified 
- Interpretations 
Actionable items  
- Follow-up tests suggested 
- Pharmacovigilance note 
- Recommendations (treatment/drugs) 

Keep concise – try for 1-2 sentences maximum including only key information 

Where values not available, replace with N/A. 

Give steps for reasons and answers.  

Include references used for support to back up statements.  

Use professional tone and language understandable by undergraduate medical students.  
'''

3.
'''
You are a clinical clerk assistant using evidence-based guidelines which you must reference for this task. 
Analyse the attached laboratory report and: 
1. identify abnormal findings 
2. explore clinical significance  
3. apply relevant guideline thresholds where needed 
4. provide management recommendations 

 
Output (few sentences - ensure most important information provided): 
- Brief summary 
- Patient demographics 
- Reason for testing 
- Items tested 
- Abnormalities flagged (include this and items tested in a table) 
- Disease identified 
- Interpretations 
- Follow-up tests suggested 
- Treatment recommendations 

Include reasoning steps and write 'N/A' where information not provided but do not leave blank.  

'''

4. 
'''
You are a clinical clerk assistant using evidence-based guidelines which you must reference for this task. Analyse the attached laboratory report and:
 1. identify abnormal findings 
 2. explore clinical significance 
 3. apply relevant guideline thresholds where needed 
 4. provide management recommendations 

 Output (1–2 sentences maximum- be consise and ensure most important information is provided): 
 - Brief summary 
 - Patient demographics 
 - Reason for testing 
 - Items tested 
 - Abnormalities flagged (include this and items tested in a table) 
 - Disease identified 
 - Interpretations 
 - Follow-up tests suggested 
 - Treatment recommendations 
 
 Include some reasoning steps and write 'N/A' where information not provided but do not leave blank.
'''

# %%
Output:
1.
'''
1. Structured Laboratory Information
| Test        | Value         | Reference | Status         |
| ----------- | ------------- | --------- | -------------- |
| Sodium      | 138 mEq/L     | 135–145   | ✅ Normal       |
| Potassium   | 4.2 mEq/L     | 3.5–5.1   | ✅ Normal       |
| Chloride    | 102 mEq/L     | 98–107    | ✅ Normal       |
| CO₂         | 24 mEq/L      | 22–30     | ✅ Normal       |
| BUN         | 18 mg/dL      | 7–20      | ✅ Normal       |
| Creatinine  | 1.1 mg/dL     | 0.6–1.2   | ✅ Normal       |
| **Glucose** | **110 mg/dL** | 70–100    | ⚠️ Mildly High |

2. Liver and Protein panel
| Test            | Value     | Reference | Status   |
| --------------- | --------- | --------- | -------- |
| Calcium         | 9.2 mg/dL | 8.5–10.2  | ✅ Normal |
| Total Protein   | 7.0 g/dL  | 6.0–8.3   | ✅ Normal |
| Albumin         | 3.8 g/dL  | 3.5–5.0   | ✅ Normal |
| Total Bilirubin | 0.8 mg/dL | 0.3–1.2   | ✅ Normal |
| ALP             | 75 U/L    | 30–120    | ✅ Normal |
| AST             | 32 U/L    | 10–40     | ✅ Normal |
| ALT             | 28 U/L    | 7–56      | ✅ Normal |


3. Complete Blood Count (CBC)
| Test       | Value     | Reference | Status   |
| ---------- | --------- | --------- | -------- |
| WBC        | 9.2 K/uL  | 4.5–11.0  | ✅ Normal |
| RBC        | 4.8 M/uL  | 4.5–5.9   | ✅ Normal |
| Hemoglobin | 14.2 g/dL | 13.5–17.5 | ✅ Normal |
| Hematocrit | 42%       | 41–53     | ✅ Normal |
| Platelets  | 245 K/uL  | 150–450   | ✅ Normal |

4. Lipid Panel
| Test                  | Value         | Reference | Status          |
| --------------------- | ------------- | --------- | --------------- |
| **Total Cholesterol** | **210 mg/dL** | <200      | ⚠️ High         |
| **Triglycerides**     | **165 mg/dL** | <150      | ⚠️ High         |
| HDL                   | 42 mg/dL      | >40       | ✅ Borderline OK |
| **LDL**               | **135 mg/dL** | <100      | ⚠️ High         |

5. Thyroid Function
| Test    | Value     | Reference | Status   |
| ------- | --------- | --------- | -------- |
| TSH     | 2.8 mIU/L | 0.4–4.0   | ✅ Normal |
| Free T4 | 1.2 ng/dL | 0.8–1.8   | ✅ Normal |

Key Clinical Interpretation
✅ Stable / Normal Systems
Electrolytes → well balanced (important for ESRD patient)
Kidney markers (BUN/Creatinine) → within range (likely due to dialysis)
Liver function → normal
Hematology → no anemia or infection
Thyroid → stable post-thyroidectomy

⚠️ Abnormal Findings & Meaning
1. Mild Hyperglycemia
Glucose: 110 mg/dL
Interpretation:
Prediabetes or stress-related hyperglycemia
Could be influenced by illness or steroids (methylprednisolone used)

2. Dyslipidemia (HIGH PRIORITY)
Total Cholesterol: 210 ↑
LDL: 135 ↑
Triglycerides: 165 ↑

👉 Particularly concerning because patient has:

Coronary artery disease (CAD)
Prior CABG
Hypertension

🚨 Actionable Clinical Findings
1. Cardiovascular Risk – HIGH PRIORITY

Problem: Elevated LDL + history of CAD
Action:

Intensify lipid control:
Consider higher-dose statin or add ezetimibe
Target LDL:
<70 mg/dL (very high-risk patient)

2. Prediabetes / Glucose Monitoring

Problem: Mild hyperglycemia
Action:

Check HbA1c
Monitor fasting glucose
Lifestyle:
Diet (renal + low sugar)
Physical activity (post-recovery)


3. ESRD Monitoring (Currently Stable)

Problem: ESRD on dialysis
Action:

Continue strict dialysis adherence
Monitor:
Potassium
Fluid balance
Phosphate (not listed here)


4. Medication Optimization Opportunity

Given labs + history:

Already on atorvastatin 40 mg
👉 May need:
Dose escalation OR combination therapy

5. No Acute Infection or Hematologic Issue
Normal WBC + CRP not elevated (implied)
👉 No action required


🧠 Integrated Clinical Insight

This patient’s main laboratory-driven risks are chronic, not acute:

Acute issue (resolved)
Lumbar radiculopathy from spinal stenosis
Chronic risks (important)
Cardiovascular disease progression
Metabolic risk (early glucose elevation)
ESRD management stability

👉 Labs confirm:

Good short-term stability
But long-term cardiovascular risk remains high

📌 Summary (Action-Oriented)
Immediate
Continue current management (stable labs)
Short-term (1–3 months)
Lipid optimization (critical)
HbA1c testing
Long-term
Aggressive cardiovascular risk reduction
Maintain dialysis + BP control
'''

2. 
'''
Brief Summary
Laboratory results are largely within normal limits except for dyslipidemia and mild hyperglycemia, indicating increased cardiovascular risk.

Patient
Stephen D Porter with ESRD on hemodialysis, coronary artery disease (post-CABG), hypertension, and history of thyroid cancer.

Demographics
57-year-old male.

Reason for Testing
Routine inpatient and chronic disease monitoring.

Items Tested
Comprehensive metabolic panel, complete blood count, lipid panel, thyroid function tests.

Abnormalities Flagged
Glucose 110 mg/dL (elevated), total cholesterol 210 mg/dL (elevated), LDL 135 mg/dL (elevated), triglycerides 165 mg/dL (elevated).

Disease Identified
Dyslipidemia with possible prediabetes.

Interpretations
Elevated lipid levels in a patient with coronary artery disease indicate high atherosclerotic cardiovascular disease risk, while mild hyperglycemia suggests early insulin resistance or medication-related effect.

Actionable Items
Follow-up Tests Suggested
HbA1c and repeat fasting lipid profile to confirm metabolic status and monitor response to therapy.
Pharmacovigilance Note
Monitor for statin-related adverse effects (hepatic dysfunction, myopathy) and hyperglycemia related to corticosteroid use.
Recommendations (Treatment/Drugs)
Escalate lipid-lowering therapy (high-intensity statin with consideration of ezetimibe), implement dietary and lifestyle modification, and maintain blood pressure and dialysis adherence.

Reasoning Steps
1. Identify abnormal laboratory values (glucose and lipid panel).
2. Correlate findings with existing comorbidities (CAD increases risk significance).
3. Apply clinical guidelines (LDL target <70 mg/dL in high-risk patients).
4. Derive management plan (further testing and treatment intensification).

References
- Laboratory data: [provided pdf]
- ACC/AHA Cholesterol Guidelines (2018 and updates)
- American Diabetes Association Standards of Care
'''


3.
'''
Brief summary: This report shows mainly dyslipidemia (total cholesterol 210 mg/dL, LDL-C 135 mg/dL, triglycerides 165 mg/dL) and mild impaired fasting glucose (glucose 110 mg/dL), while CBC, thyroid tests, electrolytes, liver tests, and calcium are within the stated laboratory reference ranges; the broader admission record also documents severe lumbar spinal stenosis with radiculopathy on MRI. In a patient with known CAD s/p CABG and ESRD on home hemodialysis, the lipid abnormalities are the most clinically important laboratory issue because secondary prevention LDL-C targets are stricter than the lab’s “normal” range.

Patient demographics: 57-year-old male, Stephen D Porter, DOB 1966-08-06. Relevant comorbidities documented in the report include ESRD on home HD, hypertension, CAD s/p CABG, lumbar spondylosis/radiculopathy, and history of thyroid cancer.

Reason for testing: The admission was for severe low back pain with inability to ambulate after a motor vehicle accident, and the report includes chemistry, CBC, lipid panel, thyroid function tests, and lumbar MRI as part of inpatient evaluation and follow-up. N/A for any explicit single laboratory-only indication because the document is a mixed hospital record rather than a stand-alone lab requisition.

Items tested: Comprehensive metabolic panel, complete blood count, lipid panel, thyroid function tests, and MRI lumbar spine. The laboratory sections specifically measured glucose/electrolytes/renal function/liver panel, blood counts, cholesterol fractions/triglycerides, TSH, and free T4.

Abnormalities flagged:
| Item tested                  |                                                                                      Result | Lab range / guideline threshold                                                                                | Flag             | Clinical significance                                                                                                                                 |
| ---------------------------- | ------------------------------------------------------------------------------------------: | -------------------------------------------------------------------------------------------------------------- | ---------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------- |
| Glucose                      |                                                                                   110 mg/dL | Lab high; ADA impaired fasting glucose = **100–125 mg/dL**                                                     | High             | Consistent with **prediabetes / impaired fasting glucose** if fasting sample; confirm with HbA1c or repeat fasting glucose.  ([Diabetes Journals][1]) |
| Total cholesterol            |                                                                                   210 mg/dL | Lab reference **<200 mg/dL**                                                                                   | High             | Hypercholesterolemia; increases ASCVD risk, especially important with known CAD/CABG.                                                                 |
| Triglycerides                |                                                                                   165 mg/dL | Lab reference **<150 mg/dL**; persistent hypertriglyceridemia generally **≥150 mg/dL**                         | High             | Mild hypertriglyceridemia; often addressed first with diet, weight/metabolic review, and secondary-cause assessment.  ([ahajournals.org][2])          |
| LDL cholesterol (calculated) |                                                                                   135 mg/dL | Lab reference **<100 mg/dL**; current ACC/AHA secondary-prevention goal **<55 mg/dL** for very-high-risk ASCVD | High             | Markedly above goal for a patient with prior CAD/CABG; suggests inadequately controlled atherogenic risk.  ([ahajournals.org][2])                     |
| MRI lumbar spine             | Severe L4-L5 stenosis; moderate-severe L5-S1 stenosis with bilateral nerve root compression | N/A                                                                                                            | Abnormal imaging | Explains back pain/radiculopathy and impaired ambulation; no acute fracture, infection, or malignancy reported.                                       |

[1]: https://diabetesjournals.org/care/article/48/Supplement_1/S27/157566/2-Diagnosis-and-Classification-of-Diabetes?utm_source=chatgpt.com "2. Diagnosis and Classification of Diabetes: Standards of Care ..."
[2]: https://www.ahajournals.org/doi/10.1161/CIR.0000000000001423?utm_source=chatgpt.com "2026 ACC/AHA/AACVPR/ABC/ACPM/ADA/AGS/APhA ..."

Disease identified: The laboratory pattern is most consistent with dyslipidemia (elevated LDL-C, triglycerides, and total cholesterol) and possible prediabetes/impaired fasting glucose if the glucose was fasting. The non-laboratory disease documented in the same report is acute exacerbation of chronic lumbar radiculopathy due to severe lumbar spinal stenosis

Interpretations: The key abnormality is LDL-C 135 mg/dL in a patient with established ASCVD (CAD/CABG), which is well above modern secondary-prevention targets; by current ACC/AHA guidance, very-high-risk ASCVD patients should generally be treated to LDL-C <55 mg/dL. The glucose of 110 mg/dL meets ADA criteria for impaired fasting glucose only if fasting, while thyroid function and CBC are reassuringly normal; renal markers appear unexpectedly normal for a patient labeled ESRD on hemodialysis, so correlate with dialysis timing and overall data integrity before drawing renal conclusions.

Follow-up tests suggested: Repeat a fasting lipid panel after adherence/therapy review; cholesterol guidelines traditionally reassess lipids 4–12 weeks after treatment change, then every 3–12 months as needed. Check HbA1c (and/or repeat fasting plasma glucose) to confirm whether the mildly elevated glucose represents prediabetes, and continue clinical monitoring for new neurologic red flags such as bowel/bladder dysfunction or progressive weakness in the setting of lumbar stenosis.

Treatment recommendations: Prioritize secondary prevention lipid management: verify adherence to the documented atorvastatin, optimize lifestyle measures, and discuss with cardiology/nephrology whether additional LDL-lowering is appropriate because the LDL-C remains far above secondary-prevention goal; in dialysis-dependent CKD, KDIGO advises not starting a statin if statin-naive, but it is reasonable to continue statin therapy if already receiving it. For the glucose abnormality, recommend diet/exercise counseling as feasible and confirmatory diabetes testing rather than medication based on this single mild value alone; for the spinal stenosis/radiculopathy, continue conservative management, PT, and urgent reassessment if red-flag neurologic symptoms develop

Reasoning steps (concise): I reviewed the uploaded report for demographics, indication, and all measured items; identified abnormalities using both the report’s flagged values and external guideline thresholds; then interpreted those abnormalities in the context of the patient’s documented CAD, ESRD, and lumbar stenosis. N/A for any additional unseen laboratory pages or fasting-status confirmation.

'''

4.
'''
Brief summary: 57-year-old man with ESRD on home hemodialysis, CAD s/p CABG, HTN, and prior thyroid cancer had mostly normal CBC/CMP/thyroid tests, but the key abnormalities were LDL 135 mg/dL, total cholesterol 210 mg/dL, triglycerides 165 mg/dL, and glucose 110 mg/dL; MRI also showed severe L4–L5/L5–S1 spinal stenosis with nerve root compression explaining radicular back pain. In secondary ASCVD prevention, LDL is well above current goal (<55 mg/dL), and glucose 110 mg/dL meets ADA impaired fasting glucose/prediabetes range (100–125 mg/dL) if fasting.

Patient demographics: Stephen D Porter, 57-year-old male, DOB 1966-08-06. Relevant background: ESRD on home HD, CAD s/p CABG, HTN, lumbar spondylosis/radiculopathy, history of thyroid cancer.

Reason for testing: Workup during admission for severe low back pain, bilateral leg radicular symptoms, and inability to ambulate after a motor vehicle accident; N/A for a single dedicated lab-only indication.

Items tested: CMP, CBC, lipid panel, thyroid function tests, and lumbar spine MRI.

Abnormalities flagged (with items tested):
| Test/item                        |                                                                                      Result | Reference / guideline threshold                             | Abnormal? |
| -------------------------------- | ------------------------------------------------------------------------------------------: | ----------------------------------------------------------- | --------- |
| Glucose (CMP)                    |                                                                                   110 mg/dL | Lab 70–100; ADA IFG **100–125 mg/dL** if fasting            | Yes       |
| Total cholesterol (lipid panel)  |                                                                                   210 mg/dL | Lab **<200 mg/dL**                                          | Yes       |
| Triglycerides (lipid panel)      |                                                                                   165 mg/dL | Lab **<150 mg/dL**                                          | Yes       |
| LDL-C (lipid panel)              |                                                                                   135 mg/dL | Lab **<100 mg/dL**; secondary prevention goal **<55 mg/dL** | Yes       |
| HDL-C (lipid panel)              |                                                                                    42 mg/dL | Lab **>40 mg/dL**                                           | No        |
| CBC                              |                                                                                         WNL | Within stated lab ranges                                    | No        |
| Thyroid tests (TSH 2.8, FT4 1.2) |                                                                                         WNL | Within stated lab ranges                                    | No        |
| MRI lumbar spine                 | Severe L4–L5 stenosis; moderate-severe L5–S1 stenosis with bilateral nerve root compression | N/A                                                         | Yes       |

Disease identified: Mixed dyslipidemia and possible prediabetes/impaired fasting glucose (if fasting sample), plus documented severe degenerative lumbar spinal stenosis with radiculopathy.

Interpretations: The most clinically important laboratory issue is undertreated atherosclerotic risk because this patient has known CAD/CABG and LDL 135 mg/dL is far above recommended secondary-prevention targets; triglycerides are only mildly elevated, and thyroid/CBC/liver/electrolytes are reassuring. Glucose 110 mg/dL is only interpretable as prediabetes if fasting, so confirmation is needed.

Follow-up tests suggested: Repeat fasting lipid panel after treatment review, HbA1c and/or repeat fasting plasma glucose to confirm dysglycemia, and ongoing neurologic reassessment for red flags (new weakness, bowel/bladder dysfunction) given MRI-confirmed stenosis.

Treatment recommendations: Continue/intensify high-intensity lipid-lowering therapy for secondary prevention and assess adherence; because he is already on statin therapy and on dialysis, continuation is reasonable, while any escalation (for example ezetimibe/PCSK9-based strategy) should be individualized with cardiology/nephrology. For glucose 110 mg/dL, recommend lifestyle counseling and confirmation testing rather than drug treatment from this single value alone; for spinal stenosis, continue conservative therapy/PT and seek urgent review if neurologic red flags appear.

Reasoning steps: Compared each reported value with the lab reference range and then overlaid guideline thresholds where more clinically relevant (ADA for fasting glucose, ACC/AHA for LDL target in secondary prevention, KDIGO for dialysis/statin context). N/A where the report did not state fasting status or a specific laboratory-only indication.

[31 sources provided, as well as sources provided below each section]
'''

# %% [markdown]
# Prompt A - best prompt (best prompt):
# You are a clinical clerk assistant. You must extract structured laboratory information and derive actionable findings from the attached lab report after analysing and dividing into specific segments of data:
#
# - Brief summary of the report
# - Patient
# - Demographics
# - Reason for testing
# - Items tested
# - Abnormalities flagged
# - Disease identified
# - Interpretations
# Actionable items
# - Follow-up tests suggested
# - Pharmacovigilance note
# - Recommendations (treatment/drugs)
#
# Keep concise – try for 1-2 sentences maximum including only key information
# Where values not available, replace with N/A.
# Give steps for reasons and answers.
# Include references used for support to back up statements.
# Use professional tone and language understandable by undergraduate medical students.

# %% [markdown]
# Output A:
# Brief Summary
# Laboratory results are largely within normal limits except for dyslipidemia and mild hyperglycemia, indicating increased cardiovascular risk.
#
# Patient
# Stephen D Porter with ESRD on hemodialysis, coronary artery disease (post-CABG), hypertension, and history of thyroid cancer.
#
# Demographics
# 57-year-old male.
#
# Reason for Testing
# Routine inpatient and chronic disease monitoring.
#
# Items Tested
# Comprehensive metabolic panel, complete blood count, lipid panel, thyroid function tests.
#
# Abnormalities Flagged
# Glucose 110 mg/dL (elevated), total cholesterol 210 mg/dL (elevated), LDL 135 mg/dL (elevated), triglycerides 165 mg/dL (elevated).
#
# Disease Identified
# Dyslipidemia with possible prediabetes.
#
# Interpretations
# Elevated lipid levels in a patient with coronary artery disease indicate high atherosclerotic cardiovascular disease risk, while mild hyperglycemia suggests early insulin resistance or medication-related effect.
#
# Actionable Items
#
# Follow-up Tests Suggested
# HbA1c and repeat fasting lipid profile to confirm metabolic status and monitor response to therapy.
#
# Pharmacovigilance Note
# Monitor for statin-related adverse effects (hepatic dysfunction, myopathy) and hyperglycemia related to corticosteroid use.
#
# Recommendations (Treatment/Drugs)
# Escalate lipid-lowering therapy (high-intensity statin with consideration of ezetimibe), implement dietary and lifestyle modification, and maintain blood pressure and dialysis adherence.
#
# Reasoning Steps
# 1. Identify abnormal laboratory values (glucose and lipid panel).
# 2. Correlate findings with existing comorbidities (CAD increases risk significance).
# 3. Apply clinical guidelines (LDL target <70 mg/dL in high-risk patients).
# 4. Derive management plan (further testing and treatment intensification).
#
# References
# - Laboratory data: [provided pdf]
# - ACC/AHA Cholesterol Guidelines (2018 and updates)
# - American Diabetes Association Standards of Care

# %% [markdown]
# Prompt B - second best (prompt 4):
#
# You are a clinical clerk assistant using evidence-based guidelines which you must reference for this task. Analyse the attached laboratory report and:
#  1. identify abnormal findings
#  2. explore clinical significance
#  3. apply relevant guideline thresholds where needed
#  4. provide management recommendations
#
#
#  Output (1–2 sentences maximum- be consise and ensure most important information is provided):
#  - Brief summary
#  - Patient demographics
#  - Reason for testing
#  - Items tested
#  - Abnormalities flagged (include this and items tested in a table)
#  - Disease identified
#  - Interpretations
#  - Follow-up tests suggested
#  - Treatment recommendations
#
#  Include some reasoning steps and write 'N/A' where information not provided but do not leave blank

# %% [markdown]
# Output B:
# Brief summary: 57-year-old man with ESRD on home hemodialysis, CAD s/p CABG, HTN, and prior thyroid cancer had mostly normal CBC/CMP/thyroid tests, but the key abnormalities were LDL 135 mg/dL, total cholesterol 210 mg/dL, triglycerides 165 mg/dL, and glucose 110 mg/dL; MRI also showed severe L4–L5/L5–S1 spinal stenosis with nerve root compression explaining radicular back pain. In secondary ASCVD prevention, LDL is well above current goal (<55 mg/dL), and glucose 110 mg/dL meets ADA impaired fasting glucose/prediabetes range (100–125 mg/dL) if fasting.
#
# Patient demographics: Stephen D Porter, 57-year-old male, DOB 1966-08-06. Relevant background: ESRD on home HD, CAD s/p CABG, HTN, lumbar spondylosis/radiculopathy, history of thyroid cancer.
#
# Reason for testing: Workup during admission for severe low back pain, bilateral leg radicular symptoms, and inability to ambulate after a motor vehicle accident; N/A for a single dedicated lab-only indication.
#
# Items tested: CMP, CBC, lipid panel, thyroid function tests, and lumbar spine MRI.
#
# Abnormalities flagged (with items tested):
# | Test/item                        |                                                                                      Result | Reference / guideline threshold                             | Abnormal? |
# | -------------------------------- | ------------------------------------------------------------------------------------------: | ----------------------------------------------------------- | --------- |
# | Glucose (CMP)                    |                                                                                   110 mg/dL | Lab 70–100; ADA IFG **100–125 mg/dL** if fasting            | Yes       |
# | Total cholesterol (lipid panel)  |                                                                                   210 mg/dL | Lab **<200 mg/dL**                                          | Yes       |
# | Triglycerides (lipid panel)      |                                                                                   165 mg/dL | Lab **<150 mg/dL**                                          | Yes       |
# | LDL-C (lipid panel)              |                                                                                   135 mg/dL | Lab **<100 mg/dL**; secondary prevention goal **<55 mg/dL** | Yes       |
# | HDL-C (lipid panel)              |                                                                                    42 mg/dL | Lab **>40 mg/dL**                                           | No        |
# | CBC                              |                                                                                         WNL | Within stated lab ranges                                    | No        |
# | Thyroid tests (TSH 2.8, FT4 1.2) |                                                                                         WNL | Within stated lab ranges                                    | No        |
# | MRI lumbar spine                 | Severe L4–L5 stenosis; moderate-severe L5–S1 stenosis with bilateral nerve root compression | N/A                                                         | Yes       |
#
# Disease identified: Mixed dyslipidemia and possible prediabetes/impaired fasting glucose (if fasting sample), plus documented severe degenerative lumbar spinal stenosis with radiculopathy.
#
# Interpretations: The most clinically important laboratory issue is undertreated atherosclerotic risk because this patient has known CAD/CABG and LDL 135 mg/dL is far above recommended secondary-prevention targets; triglycerides are only mildly elevated, and thyroid/CBC/liver/electrolytes are reassuring. Glucose 110 mg/dL is only interpretable as prediabetes if fasting, so confirmation is needed.
#
# Follow-up tests suggested: Repeat fasting lipid panel after treatment review, HbA1c and/or repeat fasting plasma glucose to confirm dysglycemia, and ongoing neurologic reassessment for red flags (new weakness, bowel/bladder dysfunction) given MRI-confirmed stenosis.
#
# Treatment recommendations: Continue/intensify high-intensity lipid-lowering therapy for secondary prevention and assess adherence; because he is already on statin therapy and on dialysis, continuation is reasonable, while any escalation (for example ezetimibe/PCSK9-based strategy) should be individualized with cardiology/nephrology. For glucose 110 mg/dL, recommend lifestyle counseling and confirmation testing rather than drug treatment from this single value alone; for spinal stenosis, continue conservative therapy/PT and seek urgent review if neurologic red flags appear.
#
# Reasoning steps: Compared each reported value with the lab reference range and then overlaid guideline thresholds where more clinically relevant (ADA for fasting glucose, ACC/AHA for LDL target in secondary prevention, KDIGO for dialysis/statin context). N/A where the report did not state fasting status or a specific laboratory-only indication.
#
# [31 sources provided, as well as sources provided below each section]

# %% [markdown]
# ### Reflection (Problem 1)
#
# 1.1: When not given a statement about which sections to include (prompts 3/4), the LLM returned too much detail going beyond the scope of what the task requested. These attempts did catch the conflicting gender issue, which prompts 1/2 did not (this may be because I mentioned it in the chat after noticing myself). A weakness of prompt 1 was asking for unnecessary formatting (tables, lists), which added complexity and length to the prompt that was not specified in the task. Other than that, the first performed quite similarly to the second which did not specify any format and just gave back semi colon separated lists. This prompt performed best and showed that including sections that you want to be included is important as well as what to do if no information is listed (write N/A). Prompt 3 didnt mention anything about missing values and the entire social history section was missing.
#
# 1.2: Tone was mentioned in all but one of these prompts to ensure professionalism and to remove emojis in output (like in prompt 1). Prompt 2 produced the shortest, easiest to read summaries – shorter than prompts 3/4 even when all 3 were given the same request of 2-3 lines. 3/4 also provided large amounts of information, but more than needed in this case (using full sentences to describe instead of shorter points for example). What 3 and 4 did well were including references when asked instead of providing information without backing like the first two. Also, the tables that 1, 2, 3 provided were easier for interpreting the abnormalities and test information.
#
# Overall, in these cases LLMs provided more information than necessary when given shorter less detailed prompts but also missed important areas which had to be explicitly mentioned. Provided examples in prompts may help.

# %% [markdown]
# ## Problem 2 Sequencing genetic report data interpretation

# %% [markdown]
# **Prompts within the genetic counselling domain can be quite complex** due to the need to:
# - Parse long documents
# - Deal with complex topics
# - Format output in very specific ways
# - Follow multi-step analytical processes
#
# This is where we can incorporate different prompt engineering techniques into a prompt for a specific genetic counselling use-case. Besides the basic prompt engineering techniques we have coverered in the class e.g. zero-/one-/few-shot prompting, have you tried chain-of-thought, tree-of-thoughts, self-consistency, lazy prompting, and
#
# **Prompt engineering is about scientific trial and error**. We encourage you to mix and match, move things around, and see what works best for you and your needs.
#
# You have also been provided an helper document "Guide_to_Interpreting_Genomic_Reports_Toolkit.pdf" to understand the essence of interpreting genetic report.

# %% [markdown]
# Objective: Extract and interpret genetic information from sequencing genetic reports.
#
# Steps:
#
# Use the sequencing report PDF files in Moodle PBL7 "NGS" folder.
#
# Design a prompt that extracts:
#
# - Brief summary, patient demographics, reason for testing
# - Genes tested, pathogenic variants, uncertain variants
# - Disease name, genetic variant interpretations
#
# Actionable items: follow-up tests, pharmacovigilance, treatment recommendations
#
# Bonus: Instruct the LLM to look up variants in online databases and reference scientific literature (if needed) using ReAct prompt engineering technique.
#
# Please document:
# - Your final prompt
# - The LLM output
# - A reflection (max 300 words) on comparing efficiency of various prompting strategies and different LLMs to extract the genetically useful information and the challenges of using LLMs for genetic report data interpretation/counselling, including accuracy, ethics, safety and professionalism.

# %%
#in this section, again I test different prompts but this time I increase complexity with each prompt for easier comparison
Prompt:

1. 
#lazy prompting
'''
Summarise the attached genetic sequencing report and identify any important findings, including genes and variants.
'''

2.
#adding a few things I can see in the reports + concise guidline
'''
You are a clinical assistant. Extract the important information from the attached genetic sequencing report.

Please identify:
- Patient demographics
- Reason for testing
- Genes tested
- Variants identified
- Disease mentioned 

Keep your answer concise.
'''

3. 
#most informative prompt with guidlines inlcuded
'''
You are a clinical genetics assistant.

Extract structured information from the genetic sequencing report attached.

Include the follwing:

Brief summary
Patient
Demographics
Reason for testing
Genes tested
Pathogenic variants
Variants of uncertain significance
Disease identified
Genetic variant interpretations

- Use only information stated in the report
- State scientific literature references where used if looking up variants in online databases
- Use a professional clinical tone - no jokes or emojis 
- If a value is missing, write 'N/A'
- Separate multiple items with semicolons
- Do not include extra explanations or text including from yourself asking additional questions

'''

# %%
Output:
#(Please include all output attached to the prompts you tried)

1.
'''
Report Overview
- Test: Whole Exome Sequencing (WES), singleton analysis
- Indication: Developmental delay, cardiac defects, seizures, dysmorphic features, hypotonia
- Main outcome: Multiple likely pathogenic/pathogenic variants identified

1. Primary Finding (Most Important)
Gene: ZEB2
- Variant: c.1349_1350del → p.Phe450Serfs*5 (frameshift)
- Zygosity: Heterozygous
- Classification: Likely pathogenic
🔍 Interpretation
- Causes a frameshift → premature stop codon → truncated protein
- Variant is rare (not found in population databases)
- Strongly associated with:
👉 Mowat-Wilson syndrome
- Intellectual disability
- Developmental delay
- Epilepsy
- Congenital anomalies
⭐ Significance
✅ This is the primary diagnosis and best explanation of the patient’s symptoms

2. Secondary Finding
Gene: NOD2
- Variant: c.855del → p.Gly286Alafs*91 (frameshift)
- Zygosity: Heterozygous
- Classification: Likely pathogenic
🔍 Interpretation
- Also a frameshift → loss of function
- Rare variant, not previously reported
Associated conditions:
- Crohn’s disease (inflammatory bowel disease)
- Blau syndrome
- Psoriatic arthritis
- Yao syndrome
⭐ Significance
⚠️ Not directly explaining current symptoms, but:
- Indicates increased susceptibility to inflammatory/autoimmune conditions

3. Carrier Status (Recessive Conditions)
These do not cause disease in this patient, but are important for future reproductive risk.
Gene: DPYS
- Variant: c.1393C>T → p.Arg465*
- Zygosity: Heterozygous
- Classification: Pathogenic
Associated disease:
- Dihydropyrimidinase deficiency (recessive metabolic disorder)
👉 Patient is a carrier only

4. Other Important Negative Findings
❌ No additional variants explaining phenotype
❌ No medically actionable ACMG secondary variants
❌ No copy number variants (CNVs) detected
❌ No chromosomal abnormalities (aneuploidy, microdeletions)

Overall Clinical Interpretation
✅ Most important conclusion:
- The ZEB2 mutation likely provides a genetic diagnosis
- Consistent with Mowat-Wilson syndrome

⚠️ Additional considerations:
- NOD2 variant → future risk for inflammatory diseases
- Carrier variants (DPYS, GJB2) → relevant for family planning

🧠 Key Takeaways (Simple)
🧬 Primary cause: ZEB2 mutation → explains developmental issues
🧬 Secondary risk: NOD2 mutation → possible immune/inflammatory conditions
🧬 Carrier status: DPYS + GJB2 → no current disease, but genetic risk for children

Recommendations from report
Genetic counselling is recommended
Future reanalysis (>1 year) may reveal additional findings
'''

2.
'''
Patient Demographics
- Name: Not specified (redacted)
- Sex: Not specified
- DOB: Not specified
- Test: Whole Exome Sequencing (singleton/proband only)

Reason for Testing
- Global developmental delay
- Mild aortic valve stenosis / aortic stenosis
- Febrile seizures
- Patent ductus arteriosus
- Hypotonia
- Dysmorphic features (e.g., hypertelorism, midface retrusion, epicanthal folds)
- Atopic dermatitis and other physical findings

Genes Tested (with reported variants)
- ZEB2
- NOD2
- DPYS
- GJB2

Variants Identified
- ZEB2: c.1349_1350del (p.Phe450Serfs*5), heterozygous → Likely pathogenic
- NOD2: c.855del (p.Gly286Alafs*91), heterozygous → Likely pathogenic
- DPYS: c.1393C>T (p.Arg465*), heterozygous → Pathogenic (carrier)
- GJB2: c.109G>A (p.Val37Ile), heterozygous → Likely pathogenic (carrier)

Diseases Mentioned
- Mowat-Wilson syndrome (ZEB2)
- Crohn disease / inflammatory bowel disease, Blau syndrome, Yao syndrome (NOD2)
- Dihydropyrimidinase deficiency (DPYS)
- Nonsyndromic hearing loss (GJB2)

'''

3.
'''
Brief Summary
Whole exome sequencing identified a heterozygous likely pathogenic variant in ZEB2 consistent with the clinical phenotype; additional likely pathogenic variant in NOD2 and carrier status variants in DPYS and GJB2 were also detected.

Patient
N/A

Demographics
Name: N/A; Sex: N/A; Date of Birth: N/A

Reason for Testing
Global developmental delay; mild aortic valve stenosis; febrile seizures; patent ductus arteriosus; hypotonia; dysmorphic features (wide anterior fontanel; hypertelorism; epicanthal folds; midface retrusion); atopic dermatitis; abnormal hair whorls

Genes Tested
ZEB2; NOD2; DPYS; GJB2

Pathogenic Variants
ZEB2: c.1349_1350del (p.Phe450Serfs5), heterozygous, likely pathogenic; NOD2: c.855del (p.Gly286Alafs91), heterozygous, likely pathogenic; DPYS: c.1393C>T (p.Arg465*), heterozygous, pathogenic; GJB2: c.109G>A (p.Val37Ile), heterozygous, likely pathogenic

Variants of Uncertain Significance
None detected

Disease Identified
Mowat-Wilson syndrome (associated with ZEB2); inflammatory bowel disease/Crohn disease susceptibility; Blau syndrome; Yao syndrome (associated with NOD2); dihydropyrimidinase deficiency (carrier, DPYS); nonsyndromic hearing loss (carrier, GJB2)

Genetic Variant Interpretations
ZEB2 variant: frameshift leading to premature termination; rare and not present in population databases; interpreted as likely pathogenic; associated with autosomal dominant Mowat-Wilson syndrome; NOD2 variant: frameshift leading to premature termination; rare; interpreted as likely pathogenic; associated with inflammatory and autoimmune conditions; DPYS variant: nonsense variant leading to premature termination; interpreted as pathogenic; carrier status for autosomal recessive disorder; GJB2 variant: missense variant with reported association to hearing loss in homozygous or compound heterozygous state; interpreted as likely pathogenic with incomplete penetrance
'''

# %% [markdown]
# Prompt A - best prompt (3):
# You are a clinical genetics assistant.
#
# Extract structured information from the genetic sequencing report attached.
#
# Include the follwing:
#
# Brief summary
# Patient
# Demographics
# Reason for testing
# Genes tested
# Pathogenic variants
# Variants of uncertain significance
# Disease identified
# Genetic variant interpretations
#
# - Use only information stated in the report
# - State scientific literature references where used if looking up variants in online databases
# - Use a professional clinical tone - no jokes or emojis
# - If a value is missing, write 'N/A'
# - Separate multiple items with semicolons
# - Do not include extra explanations or text including from yourself asking additional questions

# %% [markdown]
# Output A:
# **Brief Summary**
# Whole exome sequencing identified a heterozygous likely pathogenic variant in ZEB2 consistent with the clinical phenotype; additional likely pathogenic variant in NOD2 and carrier status variants in DPYS and GJB2 were also detected.
#
# **Patient**
# N/A
#
# **Demographics**
# Name: N/A; Sex: N/A; Date of Birth: N/A
#
# **Reason for Testing**
# Global developmental delay; mild aortic valve stenosis; febrile seizures; patent ductus arteriosus; hypotonia; dysmorphic features (wide anterior fontanel; hypertelorism; epicanthal folds; midface retrusion); atopic dermatitis; abnormal hair whorls
#
# **Genes Tested**
# ZEB2; NOD2; DPYS; GJB2
#
# **Pathogenic Variants**
# ZEB2: c.1349_1350del (p.Phe450Serfs5), heterozygous, likely pathogenic; NOD2: c.855del (p.Gly286Alafs91), heterozygous, likely pathogenic; DPYS: c.1393C>T (p.Arg465*), heterozygous, pathogenic; GJB2: c.109G>A (p.Val37Ile), heterozygous, likely pathogenic
#
# **Variants of Uncertain Significance**
# None detected
#
# **Disease Identified**
# Mowat-Wilson syndrome (associated with ZEB2); inflammatory bowel disease/Crohn disease susceptibility; Blau syndrome; Yao syndrome (associated with NOD2); dihydropyrimidinase deficiency (carrier, DPYS); nonsyndromic hearing loss (carrier, GJB2)
#
# **Genetic Variant Interpretations**
# ZEB2 variant: frameshift leading to premature termination; rare and not present in population databases; interpreted as likely pathogenic; associated with autosomal dominant Mowat-Wilson syndrome; NOD2 variant: frameshift leading to premature termination; rare; interpreted as likely pathogenic; associated with inflammatory and autoimmune conditions; DPYS variant: nonsense variant leading to premature termination; interpreted as pathogenic; carrier status for autosomal recessive disorder; GJB2 variant: missense variant with reported association to hearing loss in homozygous or compound heterozygous state; interpreted as likely pathogenic with incomplete penetrance

# %% [markdown]
# Prompt B - second best (2):
#
# You are a clinical assistant. Extract the important information from the attached genetic sequencing report.
#
# Please identify:
# - Patient demographics
# - Reason for testing
# - Genes tested
# - Variants identified
# - Disease mentioned
#
# Keep your answer concise.

# %% [markdown]
# Output B:
#
# Patient Demographics
# - Name: Not specified (redacted)
# - Sex: Not specified
# - DOB: Not specified
# - Test: Whole Exome Sequencing (singleton/proband only)
#
# Reason for Testing
# - Global developmental delay
# - Mild aortic valve stenosis / aortic stenosis
# - Febrile seizures
# - Patent ductus arteriosus
# - Hypotonia
# - Dysmorphic features (e.g., hypertelorism, midface retrusion, epicanthal folds)
# - Atopic dermatitis and other physical findings
#
# Genes Tested (with reported variants)
# - ZEB2
# - NOD2
# - DPYS
# - GJB2
#
# Variants Identified
# - ZEB2: c.1349_1350del (p.Phe450Serfs*5), heterozygous → Likely pathogenic
# - NOD2: c.855del (p.Gly286Alafs*91), heterozygous → Likely pathogenic
# - DPYS: c.1393C>T (p.Arg465*), heterozygous → Pathogenic (carrier)
# - GJB2: c.109G>A (p.Val37Ile), heterozygous → Likely pathogenic (carrier)
#
# Diseases Mentioned
# - Mowat-Wilson syndrome (ZEB2)
# - Crohn disease / inflammatory bowel disease, Blau syndrome, Yao syndrome (NOD2)
# - Dihydropyrimidinase deficiency (DPYS)
# - Nonsyndromic hearing loss (GJB2)

# %% [markdown]
# ### Reflection (Problem 2)
# The first prompt (lazy) performed the poorest. It was too verbose and unstructured, containing uneccessary information in long paragraphs. It was also the least professional containing emojis. As well as going beyond the requirements, it also did not use any references to support its points, did not handle missing values properly and did not format in a meaningful way. This would be difficult to use in a medical setting as a clician would still have to read through this information and cross check with their own resources.
#
# The second prompt (prompt B) performed well. Even without being explicitly told about missing values, it used the list of what was required to extract most useful info and where values werent provided, replaced them with "not specified". Asking for concise results was definitely beneficial and enusred the output was very easily readable and understandable by using bullet points. This output however may not be rigourous enough and was missing some important information on variants as well as a summary.
#
# The third prompt (A) performed the best with a good clear structure and inclusion of all required sections. The additional guidlines provided in this prompt allowed for better and more professional/useful formatting (using semicolons, writing N/A to handle missing values). This output wasn't too long or too short like the previous 2 prompts but included the correct amount of information and explanation. This will fit clinical standards best.
#
# I think something that could be explored futher is giving one or a few example outputs (multi-shot prompting) rather than just requesting a format like the zero shot prompts used in this pbl.

# %% [markdown]
# # End of PBL
# Your answers to this PBL will be evaluated against the three criteria:
# 1) Effectiveness of the prompt,
# 2) Accuracy and robustness of the output/response, and
# 3) Appropriate use of prompt engineering techniques and best practices of prompting.
#
# Below are links to some helper functions provided for completing your PBL, please be minded that you might need to update the code to accomondate your own needs:
# - Evaluating prompt effectiveness: https://github.com/NirDiamant/Prompt_Engineering/blob/main/all_prompt_engineering_techniques/evaluating-prompt-effectiveness.ipynb
# - Prompt optimization techniques: https://github.com/NirDiamant/Prompt_Engineering/blob/main/all_prompt_engineering_techniques/prompt-optimization-techniques.ipynb

# %%
#@title Code to convert your .ipynb to HTML in Colab
# after you execute this code block, a file uploader will appear below the block,
# upload your ipynb from there and it will automatically convert your .ipynb to HTML file
# if you cannot convert, submit your ipynb is fine also.

# Upload ipynb
from google.colab import files
f = files.upload()

# Convert ipynb to html
import subprocess
file0 = list(f.keys())[0]
_ = subprocess.run(["pip", "install", "nbconvert"])
_ = subprocess.run(["jupyter", "nbconvert", file0, "--to", "html"])

# download the html
files.download(file0[:-5]+"html")
# Out:
#      <input type="file" id="files-d034400b-aada-4c16-8fec-991c075df14d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d034400b-aada-4c16-8fec-991c075df14d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
